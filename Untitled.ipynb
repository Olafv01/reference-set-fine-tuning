# %%
import os
from os.path import join
from glob import glob

# %%
val_queries=[]
with open("/scratch/mzaffar/olaf/MSLS-val/key_mslsval.txt") as f:
    val_queries = list(f)[0]
all_queries_paths = sorted(glob(join("../datasets_vg/datasets/msls/val/queries", "**", "*.jpg"),  recursive=True))
queries_paths=[]

for query_path in all_queries_paths:
    pano_id= query_path.split('@')[7]
#     print(pano_id)
    if pano_id in val_queries:
        queries_paths.append(query_path)
#     print(s)

# %%
print(len(val_queries.split()))
# Out:
# 740

# %%
type(val_queries)
# Out:
# str

# %%
print(all_queries_paths)
# Out:
# ['../datasets_vg/datasets/msls/val/queries/@0343808.86@6170340.50@33@U@055.65376@0012.51750@ipPvepehesGLKTkllh30dA@@@@@@20180413@day_forward_cph@.jpg', '../datasets_vg/datasets/msls/val/queries/@0343817.26@6170333.66@33@U@055.65370@0012.51764@ZBEnyadhVUTN7wpm_eVuLg@@@@@@20180413@day_forward_cph@.jpg', '../datasets_vg/datasets/msls/val/queries/@0343825.83@6170327.07@33@U@055.65365@0012.51778@0jHucM9GJfHG3izCkQNZzA@@@@@@20180413@day_forward_cph@.jpg', '../datasets_vg/datasets/msls/val/queries/@0343834.94@6170319.58@33@U@055.65358@0012.51793@5XKuq6aRAz5orLkh-f2mvw@@@@@@20180413@day_forward_cph@.jpg', '../datasets_vg/datasets/msls/val/queries/@0343842.08@6171211.36@33@U@055.66159@0012.51754@5sOJhyWK_KjiLU1gUSuIDg@@@@@@20150520@day_forward_cph@.jpg', '../datasets_vg/datasets/msls/val/queries/@0343843.79@6170312.61@33@U@055.65352@0012.51807@gDyXF2viXH1tmLkRWWBjug@@@@@@20180413@day_forward_cph@.jpg', '../datasets_vg/datasets/msls/val/queries/@0343850.65@6170307.30@33@U@055.65348@0012.51819@
# ...
